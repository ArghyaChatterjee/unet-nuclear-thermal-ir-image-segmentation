# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [0.078, 0.0878, 0.0912, 0.0958, 0.1061]

yerr = [0.00053, 0.00064, 0.00081, 0.00063, 0.00089] #Error scaled 1/10th of initial error to show better in a graph

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='g', ecolor='xkcd:black', elinewidth=1.5, marker='.',
             capsize=3, capthick=1, errorevery=1)

plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [0.0857, 0.099, 0.1092, 0.0898, 0.079]

 
yerr = [0.0053, 0.00357, 0.00622, 0.00358, 0.00152] #Error scaled 1/10th of initial error to show better in a graph

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='y', ecolor='xkcd:black', elinewidth=1.5, marker='.',
             capsize=3, capthick=1, errorevery=1)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [0.0764, 0.0836, 0.0875, 0.0905, 0.099]

yerr = [0.00053, 0.00053, 0.00068, 0.0007, 0.001] #Error scaled 1/10th of initial error to show better in a graph

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='r', ecolor='xkcd:black', elinewidth=1.5, marker='.',
             capsize=3, capthick=1, errorevery=1)

plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y1 = [0.0764, 0.0836, 0.0875, 0.0905, 0.099]
y2 = [0.0857, 0.099, 0.1092, 0.0898, 0.079]
y3 = [0.078, 0.0878, 0.0912, 0.0958, 0.1061]
y4 = [0.0537, 0.0776, 0.0585, 0.0553, 0.0578]

plt.figure(1)
plt.plot(x, y1, "r-*", label='Deep Neural Network')
plt.plot(x, y2, "y-h", label='Basic Image Processing')
plt.plot(x, y3, "g-p", label='Ground Truth')
plt.plot(x, y4, "b-o", label='Complex Image Processing')
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y4 = [0.0537, 0.0776, 0.0585, 0.0553, 0.0578]

plt.figure(1)
plt.plot(x, y1, "b-*", label='Neural Network')
plt.plot(x, y2, "r-h", label='Basic Image Processing')
plt.plot(x, y3, "k-p", label='Manual Edited')
plt.plot(x, y4, "g-o", label='Complex Image Processing')
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [0.0537, 0.0776, 0.0585, 0.0553, 0.0578]

 
yerr = [0.00034, 0.00107, 0.00187, 0.00135, 0.00045] #Error scaled 1/10th of initial error to show better in a graph

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='b', ecolor='xkcd:black', elinewidth=1.5, marker='.',
             capsize=3, capthick=1, errorevery=1)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np

data = np.genfromtxt('loss function vs epoch.csv', delimiter=',', names=['Epoch', 'loss'])

plt.plot(data['Epoch'], data['loss'])

plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.xticks()
plt.yticks()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data
# Out:
# array([(  1., 0.4309), (  2., 0.1659), (  3., 0.1396), (  4., 0.1242),
#        (  5., 0.096 ), (  6., 0.0852), (  7., 0.0744), (  8., 0.0615),
#        (  9., 0.0644), ( 10., 0.0656), ( 11., 0.0591), ( 12., 0.0562),
#        ( 13., 0.0553), ( 14., 0.0525), ( 15., 0.0514), ( 16., 0.0485),
#        ( 17., 0.0557), ( 18., 0.048 ), ( 19., 0.0501), ( 20., 0.0485),
#        ( 21., 0.0431), ( 22., 0.0449), ( 23., 0.0459), ( 24., 0.0475),
#        ( 25., 0.0426), ( 26., 0.0403), ( 27., 0.0418), ( 28., 0.0408),
#        ( 29., 0.0411), ( 30., 0.04  ), ( 31., 0.0403), ( 32., 0.0408),
#        ( 33., 0.0449), ( 34., 0.0434), ( 35., 0.0407), ( 36., 0.0406),
#        ( 37., 0.0421), ( 38., 0.0398), ( 39., 0.0382), ( 40., 0.0435),
#        ( 41., 0.0403), ( 42., 0.0373), ( 43., 0.0399), ( 44., 0.0442),
#        ( 45., 0.0375), ( 46., 0.0389), ( 47., 0.0413), ( 48., 0.043 ),
#        ( 49., 0.0443), ( 50., 0.0367), ( 51., 0.0379), ( 52., 0.0379),
# ...

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np

data = np.genfromtxt('mean_iou vs epoch.csv', delimiter=',', names=['Epoch', 'mean_iou'])

plt.plot(data['Epoch'], data['mean_iou'])

plt.ylabel('mean_iou')
plt.xlabel('Epoch')
plt.xticks()
plt.yticks()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np

data = np.genfromtxt('training score vs epoch.csv', delimiter=',', names=['Epoch', 'training_score'])

plt.plot(data['Epoch'], data['training_score'])

plt.ylabel('training score')
plt.xlabel('Epoch')
plt.xticks()
plt.yticks()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np

data = np.genfromtxt('val loss vs epoch.csv', delimiter=',', names=['Epoch', 'val_loss'])

plt.plot(data['Epoch'], data['val_loss'])

plt.ylabel('validation loss')
plt.xlabel('Epoch')
plt.xticks()
plt.yticks()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np

data = np.genfromtxt('val mean iou vs epoch.csv', delimiter=',', names=['Epoch', 'val_mean_iou'])

plt.plot(data['Epoch'], data['val_mean_iou'])

plt.ylabel('validation mean iou')
plt.xlabel('Epoch')
plt.xticks()
plt.yticks()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np

data = np.genfromtxt('validation score vs epoch.csv', delimiter=',', names=['Epoch', 'val_score'])

plt.plot(data['Epoch'], data['val_score'])

plt.ylabel('validation score')
plt.xlabel('Epoch')
plt.xticks()
plt.yticks()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Bubble Frequency by Ground Truth (Combined Plot 1)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [18.33, 25.17, 30.33, 23.5, 30.5]

yerr = [2.05, 4.67, 5.76, 4.03, 3.5] 

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='r', ecolor='xkcd:red', elinewidth=1.0, marker='h',
             capsize=3, capthick=1, errorevery=1)
plt.plot(x, y, "r-h", label='Ground Truth Segmentation', linewidth=1.0)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Bubble Frequency(No. of Spots)")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Bubble Frequency by Deep Convolutional Neural Network (Combined Plot 2)

# %%
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [20.83, 23.5, 28.17, 24.17, 31.67]

yerr = [2.91, 2.87, 5.08, 4.1, 3.14] 

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='y', ecolor='xkcd:yellow', elinewidth=1.0, marker='*',
             capsize=3, capthick=1, errorevery=1)
plt.plot(x, y, "y-*", label='DCNN Segmentation', linewidth=1.0)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Bubble Frequency(No. of Spots)")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()

# %% [markdown]
# # Bubble Frequency by GT and DCNN (Combined Plot without errorbar)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y1 = [18.33, 25.17, 30.33, 23.5, 30.5]
y2 = [20.83, 23.5, 28.17, 24.17, 31.67]


plt.figure(1)
plt.plot(x, y1, "r-h", label='Ground Truth')
plt.plot(x, y2, "y-*", label='Deep Neural Network')

plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Bubble Frequency")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Bubble Frequency by Ground Truth (Single Plot)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y1 = [18.33, 25.17, 30.33, 23.5, 30.5]
#y2 = [20.83, 23.5, 28.17, 24.17, 31.67]


plt.figure(1)
plt.plot(x, y1, "r-*", label='Ground Truth')
#plt.plot(x, y2, "y-h", label='DNN')

plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Bubble Frequency")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Bubble Frequency by Deep Convolutional Neural Network (Single Plot)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
#y1 = [18.33, 25.17, 30.33, 23.5, 30.5]
y2 = [20.83, 23.5, 28.17, 24.17, 31.67]


plt.figure(1)
#plt.plot(x, y1, "r-*", label='Ground Truth')
plt.plot(x, y2, "y-h", label='DNN')

plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Bubble Frequency")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Bubble Density by Ground Truth (Combined Plot 1)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [1.1316e-7, 1.5535e-7, 1.8724e-7, 1.4506e-7, 1.8827e-7]

yerr = [1.268e-8, 2.882e-8, 3.558e-8, 2.488e-8, 2.161e-8] 

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='r', ecolor='xkcd:red', elinewidth=1.0, marker='h',
             capsize=3, capthick=1, errorevery=1)
plt.plot(x, y, "r-h", label='Ground Truth Segmentation', linewidth=1.0)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Bubble Density(Spot/micrometer^2)")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Bubble Density by Deep Convolutional Neural Network (Combined Plot 2)

# %%
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [1.2860e-7, 1.4506e-7, 1.7386e-7, 1.4917e-7, 1.9547e-7]

yerr = [1.797e-8, 1.773e-8, 3.136e-8, 2.531e-8, 1.941e-8] 
plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='y', ecolor='xkcd:yellow', elinewidth=1.0, marker='*',
             capsize=3, capthick=1, errorevery=1)
plt.plot(x, y, "y-*", label='DCNN segmentation', linewidth=1.0)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Bubble Density(Spot/micrometer^2)")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()

# %% [markdown]
# # Dry Area Fraction by DCNN, BIP, GT and CIP (Combined without errorbar)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y1 = [0.0764, 0.0836, 0.0875, 0.0905, 0.099]
y2 = [0.0857, 0.099, 0.1092, 0.0898, 0.079]
y3 = [0.078, 0.0878, 0.0912, 0.0958, 0.1061]
y4 = [0.0537, 0.0776, 0.0585, 0.0553, 0.0578]

plt.figure(1)
plt.plot(x, y1, "r-*", label='Deep Neural Network')
plt.plot(x, y2, "y-h", label='Basic Image Processing')
plt.plot(x, y3, "g-p", label='Ground Truth')
plt.plot(x, y4, "b-o", label='Complex Image Processing')
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Dry Area Fraction by Deep Convolutional Neural Network (Combined Plot 1)

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [0.0764, 0.0836, 0.0875, 0.0905, 0.099]

yerr = [0.0036, 0.0042, 0.0053, 0.0055, 0.0075] 

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='r', ecolor='xkcd:red', elinewidth=1.0, marker='*',
             capsize=3, capthick=1, errorevery=1)
plt.plot(x, y, "r-*", label='Deep Convolutional Neural Network', linewidth=1.0)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Dry Area Fraction by Ground Truth (Combined Plot 2)

# %%
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [0.078, 0.0878, 0.0912, 0.0958, 0.1061]

yerr = [0.0037, 0.0048, 0.006, 0.0051, 0.0066] 

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='g', ecolor='xkcd:green', elinewidth=1.0, marker='p',
             capsize=3, capthick=1, errorevery=1)
plt.plot(x, y, "g-p", label='Ground Truth', linewidth=1.0)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()

# %% [markdown]
# # Dry Area Fraction by Basic Image Processing (Combined Plot 3)

# %%
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [0.0857, 0.099, 0.1092, 0.0898, 0.079]

yerr = [0.0377, 0.0219, 0.0459, 0.0239, 0.0105] 

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='y', ecolor='xkcd:yellow', elinewidth=1.0, marker='h',
             capsize=3, capthick=1, errorevery=1)
plt.plot(x, y, "y-h", label='Basic Image Processing', linewidth=1.0)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()

# %% [markdown]
# # Dry Area Fraction by Complex Image Processing (Combined Plot 4)

# %%
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = [600, 700, 800, 900, 1100]
y = [0.0537, 0.0776, 0.0585, 0.0553, 0.0578]

yerr = [0.0027, 0.0088, 0.012, 0.0102, 0.0033] 

plt.errorbar(x, y, xerr=None, yerr=yerr, label=None, fmt='-', color='b', ecolor='xkcd:blue', elinewidth=1.0, marker='o',
             capsize=3, capthick=1, errorevery=1)
plt.plot(x, y, "b-o", label='Complex Image Processing', linewidth=1.0)
plt.xlabel("heat flux (kw/m^2)")
plt.ylabel("Dry Area Fraction")
plt.xticks()
plt.yticks()
plt.legend(fontsize = 6)
plt.show()

# %% [markdown]
# # Percentage of Images vs F-Score

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np

data = np.genfromtxt('Image_Number vs F_score.csv', delimiter=',', names=['F_score', 'Image_Number'])

plt.plot(data['F_score'], data['Image_Number'])

plt.ylabel('% of Images')
plt.xlabel('F-score')
plt.xticks()
plt.yticks()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
